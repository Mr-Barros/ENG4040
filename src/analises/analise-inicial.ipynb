# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '../../dados/base/'

df = pd.read_csv(f'{path}lichess-2013-07.csv')
df.head(10)
# Out:
#                   Event                          Site        Date Round  \
# 0      Rated Blitz game  https://lichess.org/c1rfp1ck  ????.??.??     ?
# 1      Rated Blitz game  https://lichess.org/stzfm8mg  ????.??.??     ?
# 2     Rated Bullet game  https://lichess.org/bpt2ceyi  ????.??.??     ?
# 3      Rated Blitz game  https://lichess.org/82mv3vux  ????.??.??     ?
# 4      Rated Blitz game  https://lichess.org/b6wt46iq  ????.??.??     ?
# 5  Rated Classical game  https://lichess.org/vnj19xwf  ????.??.??     ?
# 6      Rated Blitz game  https://lichess.org/57zwbipf  ????.??.??     ?
# 7      Rated Blitz game  https://lichess.org/8m2pej74  ????.??.??     ?
# 8  Rated Classical game  https://lichess.org/1764cioj  ????.??.??     ?
# 9      Rated Blitz game  https://lichess.org/ek4fjghr  ????.??.??     ?
#
#              White            Black Result     UTCDate   UTCTime WhiteElo  \
# 0  dragansimic1946            aicho    0-1  2013.06.30  22:05:06     1685
# ...

# %%
df.describe()
# Out:
#        WhiteRatingDiff  BlackRatingDiff
# count      9993.000000      9993.000000
# mean          0.304713        -2.786451
# std          38.470481        41.603590
# min        -417.000000      -518.000000
# 25%         -10.000000       -12.000000
# 50%           3.000000        -3.000000
# 75%          10.000000        10.000000
# max         524.000000       443.000000

# %%
print('Valores únicos da coluna Event:')
print(df.Event.unique())
print('\nValores únicos da coluna Date:')
print(df.Date.unique())
print('\nValores únicos da coluna Round:')
print(df.Round.unique())
print('\nValores únicos da coluna Result:')
print(df.Result.unique())
# Out:
# Valores únicos da coluna Event:
# ['Rated Blitz game' 'Rated Bullet game' 'Rated Classical game'
#  'Rated Correspondence game'
#  'Rated Blitz tournament https://lichess.org/tournament/9zgf350e'
#  'Rated Bullet tournament https://lichess.org/tournament/68gjypew'
#  'Rated Blitz tournament https://lichess.org/tournament/i1fiwlgk'
#  'Rated Blitz tournament https://lichess.org/tournament/ydvesvai'
#  'Rated Blitz tournament https://lichess.org/tournament/02had06t'
#  'Rated Blitz tournament https://lichess.org/tournament/xpwue0nd'
#  'Rated Blitz tournament https://lichess.org/tournament/q4a0a3aj'
#  'Rated Bullet tournament https://lichess.org/tournament/lrovdzh3'
#  'Rated Blitz tournament https://lichess.org/tournament/wdwmc0l1'
#  'Rated Blitz tournament https://lichess.org/tournament/b0ii9jds'
#  'Rated Bullet tournament https://lichess.org/tournament/n1o9zh48'
#  'Rated Blitz tournament https://lichess.org/tournament/ryauome5'
# ...
